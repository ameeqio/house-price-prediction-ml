# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
# necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
# display all the columns
pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# Better plotting
plt.rcParams["figure.figsize"] = (10, 6)

# %%
df: pd.DataFrame = pd.read_csv(r"C:\Users\donalduck\HOUSE_PRICE_PREDICTION\data\raw\AmesHousing.csv")
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   str
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   str
#  7   Alley            198 non-null    str
#  8   Lot Shape        2930 non-null   str
#  9   Land Contour     2930 non-null   str
#  10  Utilities        2930 non-null   str
#  11  Lot Config       2930 non-null   str
#  12  Land Slope       2930 non-null   str
#  13  Neighborhood     2930 non-null   str
#  14  Condition 1      2930 non-null   str
#  15  Condition 2      2930 non-null   str
#  16  Bldg Type        2930 non-null   str
#  17  House Style      2930 non-null   str
# ...

# %%
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
df.describe(include = 'object') # type: ignore
# Out:
#        MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# count       2930   2930   198      2930         2930      2930       2930
# unique         7      2     2         4            4         3          5
# top           RL   Pave  Grvl       Reg          Lvl    AllPub     Inside
# freq        2273   2918   120      1859         2633      2927       2140
#
#        Land Slope Neighborhood Condition 1 Condition 2 Bldg Type House Style  \
# count        2930         2930        2930        2930      2930        2930
# unique          3           28           9           8         5           8
# top           Gtl        NAmes        Norm        Norm      1Fam      1Story
# freq         2789          443        2522        2900      2425        1481
#
#        Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type Exter Qual  \
# count        2930      2930         2930         2930         1155       2930
# ...

# %%
# missing values
missing_vars = ['Pool QC', 'Misc Feature', 'Alley', 'Fence', 'Mas Vnr Type', 'Fireplace Qu', 'Lot Frontage']
df.isnull().sum().sort_values(ascending = False)
# Out:
# Pool QC            2917
# Misc Feature       2824
# Alley              2732
# Fence              2358
# Mas Vnr Type       1775
# Fireplace Qu       1422
# Lot Frontage        490
# Garage Qual         159
# Garage Yr Blt       159
# Garage Cond         159
# Garage Finish       159
# Garage Type         157
# Bsmt Exposure        83
# BsmtFin Type 2       81
# Bsmt Qual            80
# Bsmt Cond            80
# BsmtFin Type 1       80
# Mas Vnr Area         23
# Bsmt Full Bath        2
# Bsmt Half Bath        2
# Total Bsmt SF         1
# BsmtFin SF 1          1
# BsmtFin SF 2          1
# Garage Area           1
# Garage Cars           1
# Bsmt Unf SF           1
# Electrical            1
# Lot Shape             0
# Street                0
# Lot Area              0
# MS SubClass           0
# MS Zoning             0
# Order                 0
# PID                   0
# House Style           0
# Bldg Type             0
# Condition 2           0
# Condition 1           0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Target-variable

# %%
target_var = 'SalePrice'
df[target_var].describe()
# Out:
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
skewness_tagret_var = df[target_var].skew().round(3) # type: ignore
print(f"skewness : {skewness_tagret_var}")
# Out:
# skewness : 1.744

# %%
sns.histplot(data = df, x = target_var, bins = 30, kde = True)
plt.title("Distribution of sale-price of houses (target)")
# Out:
# Text(0.5, 1.0, 'Distribution of sale-price of houses (target)')

# %%
catg_features = ['MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour',
       'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
       'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
       'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual',
       'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
       'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
       'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
       'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual',
       'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature',
       'Sale Type', 'Sale Condition']

quant_features = ['Order', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area',
       'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add',
       'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF',
       'Total Bsmt SF', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
       'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
       'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd',
       'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Area',
       'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
       'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold',
       'SalePrice']

# %%
# correlation of the numeric features with the target variable 
corr: pd.Series = df.corr(numeric_only = True)[target_var].sort_values(ascending = False)
corr
# Out:
# SalePrice          1.000000
# Overall Qual       0.799262
# Gr Liv Area        0.706780
# Garage Cars        0.647877
# Garage Area        0.640401
# Total Bsmt SF      0.632280
# 1st Flr SF         0.621676
# Year Built         0.558426
# Full Bath          0.545604
# Year Remod/Add     0.532974
# Garage Yr Blt      0.526965
# Mas Vnr Area       0.508285
# TotRms AbvGrd      0.495474
# Fireplaces         0.474558
# BsmtFin SF 1       0.432914
# Lot Frontage       0.357318
# Wood Deck SF       0.327143
# Open Porch SF      0.312951
# Half Bath          0.285056
# Bsmt Full Bath     0.276050
# 2nd Flr SF         0.269373
# Lot Area           0.266549
# Bsmt Unf SF        0.182855
# Bedroom AbvGr      0.143913
# Screen Porch       0.112151
# Pool Area          0.068403
# Mo Sold            0.035259
# 3Ssn Porch         0.032225
# BsmtFin SF 2       0.005891
# Misc Val          -0.015691
# Yr Sold           -0.030569
# Order             -0.031408
# Bsmt Half Bath    -0.035835
# ...

# %%
# histogram-plots for selected numeric vars
vars_highcorr = ['Overall Qual', 'Gr Liv Area', 'Garage Area', 'Garage Cars', 'Total Bsmt SF', '1st Flr SF', 'Year Built', 'TotRms AbvGrd']
for var in vars_highcorr :
    plt.figure(figsize = (7, 6))
    sns.histplot(data = df, x = var, kde = True)

# %%
garage_vars = ['Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual', 'Garage Cond']
df[df['Garage Area'] == 0][garage_vars].head()
# garage area == 0 simply means the house doesn't contain a garage
# Out:
#     Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 27          NaN            NaN           NaN          0.0          0.0
# 119         NaN            NaN           NaN          0.0          0.0
# 125         NaN            NaN           NaN          0.0          0.0
# 129         NaN            NaN           NaN          0.0          0.0
# 130         NaN            NaN           NaN          0.0          0.0
#
#     Garage Qual Garage Cond
# 27          NaN         NaN
# 119         NaN         NaN
# 125         NaN         NaN
# 129         NaN         NaN
# 130         NaN         NaN

# %%
df[df['Garage Area'] == 0][garage_vars].tail()
# Out:
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 2913         NaN            NaN           NaN          0.0          0.0
# 2916         NaN            NaN           NaN          0.0          0.0
# 2918         NaN            NaN           NaN          0.0          0.0
# 2919         NaN            NaN           NaN          0.0          0.0
# 2927         NaN            NaN           NaN          0.0          0.0
#
#      Garage Qual Garage Cond
# 2913         NaN         NaN
# 2916         NaN         NaN
# 2918         NaN         NaN
# 2919         NaN         NaN
# 2927         NaN         NaN

# %%
df[df['Garage Area'] == 0][garage_vars].shape
# Out:
# (157, 7)

# %%
for gar_var in garage_vars :
    print(f"{gar_var} missing value : {df[gar_var].isnull().sum()}")
# Out:
# Garage Type missing value : 157
# Garage Yr Blt missing value : 159
# Garage Finish missing value : 159
# Garage Cars missing value : 1
# Garage Area missing value : 1
# Garage Qual missing value : 159
# Garage Cond missing value : 159

# %%
# most of the missing values in the garage vars corresponds to no garage for the house
# actual missing values in the garage cols
print("Garage Qual missing value : 2")
print('Garage Cond missing value : 2')
print("Garage Yr Blt missing value : 2")
print("Garage Finish missing value : 2")
# Out:
# Garage Qual missing value : 2
# Garage Cond missing value : 2
# Garage Yr Blt missing value : 2
# Garage Finish missing value : 2

# %%
bsmt_vars = df.columns[df.columns.str.startswith("Bsmt")].to_list()
print(f"basement features : {bsmt_vars}")
df[df['Total Bsmt SF'] == 0][bsmt_vars + ['Total Bsmt SF']].head()
# total-bmst sf == 0 might correspond to that the house is not having a basement
# Out:
# basement features : ['Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Bsmt Full Bath', 'Bsmt Half Bath']
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 83        NaN       NaN           NaN            NaN           0.0
# 154       NaN       NaN           NaN            NaN           0.0
# 206       NaN       NaN           NaN            NaN           0.0
# 243       NaN       NaN           NaN            NaN           0.0
# 273       NaN       NaN           NaN            NaN           0.0
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Bsmt Full Bath  Bsmt Half Bath  \
# 83             NaN           0.0          0.0             0.0             0.0
# 154            NaN           0.0          0.0             0.0             0.0
# 206            NaN           0.0          0.0             0.0             0.0
# ...

# %%
df[df['Total Bsmt SF'] == 0].shape
# Out:
# (79, 82)

# %%
df[bsmt_vars + ['Total Bsmt SF']].isnull().sum()
# Out:
# Bsmt Qual         80
# Bsmt Cond         80
# Bsmt Exposure     83
# BsmtFin Type 1    80
# BsmtFin SF 1       1
# BsmtFin Type 2    81
# BsmtFin SF 2       1
# Bsmt Unf SF        1
# Bsmt Full Bath     2
# Bsmt Half Bath     2
# Total Bsmt SF      1
# dtype: int64

# %%
sns.histplot(data = df, x = 'Fireplaces', kde = True)
# Out:
# <Axes: xlabel='Fireplaces', ylabel='Count'>

# %%
df[df['Fireplaces'] == 0].shape
# Out:
# (1422, 82)

# %%
df[df['Fireplaces'] == 0].head()
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1       2  526350040           20        RH          80.0     11622   Pave
# 2       3  526351010           20        RL          81.0     14267   Pave
# 6       7  527127150          120        RL          41.0      4920   Pave
# 7       8  527145080          120        RL          43.0      5005   Pave
# 11     12  527165230           20        RL           NaN      7980   Pave
#
#    Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 1    NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2    NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 6    NaN       Reg          Lvl    AllPub     Inside        Gtl      StoneBr
# 7    NaN       IR1          HLS    AllPub     Inside        Gtl      StoneBr
# 11   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
df['Fireplace Qu'].isnull().sum()
# Out:
# np.int64(1422)

# %%
df.describe(include = 'object') # type: ignore
# Out:
#        MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# count       2930   2930   198      2930         2930      2930       2930
# unique         7      2     2         4            4         3          5
# top           RL   Pave  Grvl       Reg          Lvl    AllPub     Inside
# freq        2273   2918   120      1859         2633      2927       2140
#
#        Land Slope Neighborhood Condition 1 Condition 2 Bldg Type House Style  \
# count        2930         2930        2930        2930      2930        2930
# unique          3           28           9           8         5           8
# top           Gtl        NAmes        Norm        Norm      1Fam      1Story
# freq         2789          443        2522        2900      2425        1481
#
#        Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type Exter Qual  \
# count        2930      2930         2930         2930         1155       2930
# ...

# %%
sus_catg_ftrs = ['Alley', 'Neighborhood', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Pool QC',	'Fence', 'Misc Feature' ]
for ftr in sus_catg_ftrs :
    plt.figure(figsize = (10, 6))
    sns.countplot(data = df, y = ftr)

# %%
for ftr in sus_catg_ftrs :
    print(f"{ftr} val counts : {df[ftr].value_counts().sort_values(ascending = False)}\n")
# Out:
# Alley val counts : Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64
#
# Neighborhood val counts : Neighborhood
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# NWAmes     131
# SawyerW    125
# Mitchel    114
# BrkSide    108
# Crawfor    103
# IDOTRR      93
# Timber      72
# NoRidge     71
# StoneBr     51
# SWISU       48
# ClearCr     44
# MeadowV     37
# BrDale      30
# Blmngtn     28
# Veenker     24
# NPkVill     23
# Blueste     10
# Greens       8
# GrnHill      2
# Landmrk      1
# Name: count, dtype: int64
#
# Exterior 1st val counts : Exterior 1st
# VinylSd    1026
# MetalSd     450
# HdBoard     442
# Wd Sdng     420
# Plywood     221
# CemntBd     126
# BrkFace      88
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# CBlock        2
# Stone         2
# PreCast       1
# ImStucc       1
# Name: count, dtype: int64
#
# ...

# %%
sus_catg_ftrs
# Out:
# ['Alley',
#  'Neighborhood',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Mas Vnr Type',
#  'Pool QC',
#  'Fence',
#  'Misc Feature']

# %%
for ftr in sus_catg_ftrs :
    plt.figure(figsize = (8, 8))
    sns.boxplot(data = df, x = target_var, y = ftr)

# %%
df.groupby("Neighborhood")['SalePrice'].agg(["count", "min", "mean", "std", "median", "max"]).sort_values("mean", ascending = False)
# Out:
#               count     min           mean            std    median     max
# Neighborhood
# NoRidge          71  190000  330319.126761  101444.662927  302000.0  755000
# StoneBr          51  130000  324229.196078  119273.020694  319000.0  591587
# NridgHt         166  154000  322018.265060   95932.354274  317750.0  615000
# GrnHill           2  230000  280000.000000   70710.678119  280000.0  330000
# Veenker          24  150000  248314.583333   65474.949540  250250.0  385000
# Timber           72  137500  246599.541667   69326.471547  232106.5  425000
# Somerst         182  139000  229707.324176   57437.392588  225500.0  468000
# ClearCr          44  107500  208662.090909   51280.213463  197500.0  328000
# Crawfor         103   90350  207550.834951   65230.183286  200624.0  392500
# CollgCr         267  110000  201803.434457   54187.843749  200000.0  475000
# Blmngtn          28  156820  196661.678571   29317.511457  191500.0  264561
# ...

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
vars_highcorr
# Out:
# ['Overall Qual',
#  'Gr Liv Area',
#  'Garage Area',
#  'Garage Cars',
#  'Total Bsmt SF',
#  '1st Flr SF',
#  'Year Built',
#  'TotRms AbvGrd']

# %%
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
df[df['Garage Yr Blt'] > 2026]
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2260   2261  916384070           20        RL          68.0      8298   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 2260   NaN       IR1          HLS    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 2260       Timber        Norm        Norm      1Fam      1Story             8
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 2260             5        2006            2007        Hip   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 2260      VinylSd      VinylSd          NaN           NaN         Gd
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 2260         TA      PConc        Gd        TA            Av            GLQ
#
# ...

# %%
df.sample(6)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1959   1960  535451040           20        RL          60.0      7200   Pave
# 2312   2313  527107020           60        RL           NaN     13041   Pave
# 822     823  906378110           20        RL          71.0      9178   Pave
# 1961   1962  535451110           20        RL          60.0      7200   Pave
# 2716   2717  905107300           80        RL           NaN      7176   Pave
# 72       73  531367050           60        RL          76.0     10142   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1959   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2312   NaN       IR2          Lvl    AllPub     Inside        Gtl
# 822    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1961   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2716   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# ...

# %% [markdown]
# ## DATA-PREPROCESSING PLAN

# %% [markdown]
# 1. Columns to Drop
# - Order, PID
#
# 2. Missing Value Strategy and outliers
#
# 3. Numerical Features
# - ['Lot Frontage', 'Lot Area',
#        'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add',
#        'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF',
#        'Total Bsmt SF', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd',
#        'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Area',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold',
#        'SalePrice']
#
# 4. Nominal Categorical Features
# - ['MS SubClass', 'MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour',
#        'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
#        'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating',
#        'Central Air', 'Electrical', 'Functional',
#        'Garage Type', 'Garage Finish', 'Condition 1', 'Condition 2',
#        'Paved Drive', 'Fence', 'Misc Feature',
#        'Sale Type', 'Sale Condition']
#
# 5. Ordinal Categorical Features
# - ['Exter Qual',
#     'Exter Cond', 'Bsmt Qual', 'Bsmt Cond', 'Heating QC', 'Kitchen Qual', 'Fireplace Qu', 'Garage Qual', 'Garage Cond',
#     'Pool QC']
#
# 6. Feature Engineering Ideas
#
# 7. Scaling Strategy ✅

# %%
num_features = ['Lot Frontage', 'Lot Area',
       'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add',
       'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF',
       'Total Bsmt SF', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
       'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
       'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd',
       'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Area',
       'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
       'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold',
       'SalePrice']

print("NUMERICAL FEATURES MISSING VALUES-\n")
num_ftrs_missing = []
for ftrs in num_features :
    if df[ftrs].isnull().sum() > 0 :
       print(f"'{ftrs}' missing value : {df[ftrs].isnull().sum()}")
       num_ftrs_missing.append(ftrs)
    else :
       continue
# Out:
# NUMERICAL FEATURES MISSING VALUES-
#
# 'Lot Frontage' missing value : 490
# 'Mas Vnr Area' missing value : 23
# 'BsmtFin SF 1' missing value : 1
# 'BsmtFin SF 2' missing value : 1
# 'Bsmt Unf SF' missing value : 1
# 'Total Bsmt SF' missing value : 1
# 'Bsmt Full Bath' missing value : 2
# 'Bsmt Half Bath' missing value : 2
# 'Garage Yr Blt' missing value : 159
# 'Garage Cars' missing value : 1
# 'Garage Area' missing value : 1

# %%
nom_catg_features = ['MS SubClass', 'MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour',
       'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 
       'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
       'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'Bsmt Exposure',
       'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 
       'Central Air', 'Electrical', 'Functional',
       'Garage Type', 'Garage Finish', 'Condition 1', 'Condition 2', 
       'Paved Drive', 'Fence', 'Misc Feature',
       'Sale Type', 'Sale Condition']

print("NOMINAL CATG FEATURES MISSING VALUES-\n")
nom_catg_ftrs_missing = []
for ftr in nom_catg_features :
    if df[ftr].isnull().sum() > 0 :
        print(f"'{ftr}' missing values : {df[ftr].isnull().sum()}")
        nom_catg_ftrs_missing.append(ftr)
    else :
        continue
# Out:
# NOMINAL CATG FEATURES MISSING VALUES-
#
# 'Alley' missing values : 2732
# 'Mas Vnr Type' missing values : 1775
# 'Bsmt Exposure' missing values : 83
# 'BsmtFin Type 1' missing values : 80
# 'BsmtFin Type 2' missing values : 81
# 'Electrical' missing values : 1
# 'Garage Type' missing values : 157
# 'Garage Finish' missing values : 159
# 'Fence' missing values : 2358
# 'Misc Feature' missing values : 2824

# %%
ord_catg_features =  ['Exter Qual',
    'Exter Cond', 'Bsmt Qual', 'Bsmt Cond', 'Heating QC', 'Kitchen Qual', 'Fireplace Qu', 'Garage Qual', 'Garage Cond', 
    'Pool QC']

print("ORDINAL CATG FEATURES MISSING VALUES -\n")
ord_catg_ftrs_missing = []
for ftrs in ord_catg_features :
    if df[ftrs].isnull().sum() > 0 :
        print(f"'{ftrs}' missing value : {df[ftrs].isnull().sum()}")
        ord_catg_ftrs_missing.append(ftrs)
    else :
        continue
# Out:
# ORDINAL CATG FEATURES MISSING VALUES -
#
# 'Bsmt Qual' missing value : 80
# 'Bsmt Cond' missing value : 80
# 'Fireplace Qu' missing value : 1422
# 'Garage Qual' missing value : 159
# 'Garage Cond' missing value : 159
# 'Pool QC' missing value : 2917

# %%
one_hot_enc_nomctg_ftrs = []
label_enc_nomctg_ftrs = []
for ftr in nom_catg_features :
    if len(df[ftr].unique()) > 2 :
        one_hot_enc_nomctg_ftrs.append(ftr)
    else :
        label_enc_nomctg_ftrs.append(ftr)
        continue

print(f"One hot encoding (nom_catg) -\n{one_hot_enc_nomctg_ftrs}\n")
print(f"Label encoding (nom_catg) -\n{label_enc_nomctg_ftrs}")
# Out:
# One hot encoding (nom_catg) -
# ['MS SubClass', 'MS Zoning', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Electrical', 'Functional', 'Garage Type', 'Garage Finish', 'Condition 1', 'Condition 2', 'Paved Drive', 'Fence', 'Misc Feature', 'Sale Type', 'Sale Condition']
#
# Label encoding (nom_catg) -
# ['Street', 'Central Air']

# %%
for ftr in ord_catg_features:
    print(f"'{ftr}' unique_value : {len(df[ftr].unique())}")
# Out:
# 'Exter Qual' unique_value : 4
# 'Exter Cond' unique_value : 5
# 'Bsmt Qual' unique_value : 6
# 'Bsmt Cond' unique_value : 6
# 'Heating QC' unique_value : 5
# 'Kitchen Qual' unique_value : 5
# 'Fireplace Qu' unique_value : 6
# 'Garage Qual' unique_value : 6
# 'Garage Cond' unique_value : 6
# 'Pool QC' unique_value : 5

# %%
df[num_features].sample(15)
# Out:
#       Lot Frontage  Lot Area  Overall Qual  Overall Cond  Year Built  \
# 2044         107.0     12888             7             8        1937
# 821           65.0     10816             9             5        2008
# 51           100.0     18494             6             5        2005
# 1500          65.0      6040             4             5        1955
# 1089           NaN      8010             7             5        2002
# 2142          60.0      7200             5             5        1972
# 760           60.0     10320             6             7        1915
# 1878           NaN     10624             5             4        1964
# 41            90.0     11520             9             5        2005
# 1221          50.0      7420             5             6        1939
# 2460          72.0      8640             8             5        2006
# 1029          80.0     10400             6             5        1976
# 2009          50.0      6125             5             7        1939
# ...

# %%
num_ftrs_missing
# Out:
# ['Lot Frontage',
#  'Mas Vnr Area',
#  'BsmtFin SF 1',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Garage Yr Blt',
#  'Garage Cars',
#  'Garage Area']

# %%
for ftr in num_ftrs_missing :
    plt.figure(figsize = (8, 6))
    sns.histplot(data = df, x = ftr, kde =  True)

# %%
for ftr in num_ftrs_missing :
    print(f"'{ftr}' median : {df[ftr].median()}")
# Out:
# 'Lot Frontage' median : 68.0
# 'Mas Vnr Area' median : 0.0
# 'BsmtFin SF 1' median : 370.0
# 'BsmtFin SF 2' median : 0.0
# 'Bsmt Unf SF' median : 466.0
# 'Total Bsmt SF' median : 990.0
# 'Bsmt Full Bath' median : 0.0
# 'Bsmt Half Bath' median : 0.0
# 'Garage Yr Blt' median : 1979.0
# 'Garage Cars' median : 2.0
# 'Garage Area' median : 480.0

# %%
print(num_ftrs_missing)
# Out:
# ['Lot Frontage', 'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Yr Blt', 'Garage Cars', 'Garage Area']

# %%
print(nom_catg_ftrs_missing)
# Out:
# ['Alley', 'Mas Vnr Type', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Electrical', 'Garage Type', 'Garage Finish', 'Fence', 'Misc Feature']

# %%
for ftr in nom_catg_ftrs_missing :
    plt.figure(figsize = (8, 7))
    sns.countplot(data = df, x = ftr)

# %%
print(ord_catg_ftrs_missing)
# Out:
# ['Bsmt Qual', 'Bsmt Cond', 'Fireplace Qu', 'Garage Qual', 'Garage Cond', 'Pool QC']

# %%
for ftr in ord_catg_ftrs_missing :
    plt.figure(figsize = (8, 7))
    sns.countplot(data = df, x = ftr)

# %% [markdown]
# MISSING VALUE CODE

# %%
from src.missing_val import MissingValueHandler

handler = MissingValueHandler(df)
df_no_missing = handler.transform()

# %%
df_no_missing.isnull().sum()
# Out:
# Order                0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage         0
# Lot Area             0
# Street               0
# Alley                0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type         0
# Mas Vnr Area         0
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual            0
# Bsmt Cond            0
# Bsmt Exposure        0
# BsmtFin Type 1       0
# BsmtFin SF 1         0
# BsmtFin Type 2       0
# BsmtFin SF 2         0
# Bsmt Unf SF          0
# Total Bsmt SF        0
# ...

# %%
df_no_missing.head(3)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  None       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1  None       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2  None       IR1          Lvl    AllPub     Corner        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             6             5
# 1       Feedr        Norm      1Fam      1Story             5             6
# 2        Norm        Norm      1Fam      1Story             6             6
#
# ...

# %% [markdown]
# FEATURE ENGINEERING CODE

# %%
from src.feature_engineering import FeatureEngineer
ftr_engineer = FeatureEngineer(df_no_missing)

df_new: pd.DataFrame = ftr_engineer.transform()
df_new.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0           20        RL         141.0     31770   Pave  None       IR1
# 1           20        RH          80.0     11622   Pave  None       Reg
# 2           20        RL          81.0     14267   Pave  None       IR1
# 3           20        RL          93.0     11160   Pave  None       Reg
# 4           60        RL          74.0     13830   Pave  None       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 1          Lvl    AllPub     Inside        Gtl        NAmes       Feedr
# 2          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 3          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 4          Lvl    AllPub     Inside        Gtl      Gilbert        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# ...
